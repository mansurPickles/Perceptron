# %%
#kind of works, but bias is whack. Sent

# dataset.py

#
# 5x7 dot-matrix fonts
#
# Converted from hexadecimal and rotated counter-clockwise.
#
# Training data from https://github.com/noopkat/oled-font-5x7
# Test data from https://geoffg.net/Downloads/GLCD_Driver/glcd_library_1_0.h
#

TRAINING_DATA = [
    [
        '.###.',
        '#...#',
        '#...#',
        '#...#',
        '#####',
        '#...#',
        '#...#',
    ],
    [
        '####.',
        '#...#',
        '#...#',
        '####.',
        '#...#',
        '#...#',
        '####.',
    ],
    [
        '.###.',
        '#...#',
        '#....',
        '#....',
        '#....',
        '#...#',
        '.###.',
    ],
    [
        '###..',
        '#..#.',
        '#...#',
        '#...#',
        '#...#',
        '#..#.',
        '###..',
    ],
    [
        '#####',
        '#....',
        '#....',
        '####.',
        '#....',
        '#....',
        '#####',
    ],
    [
        '#####',
        '#....',
        '#....',
        '###..',
        '#....',
        '#....',
        '#....',
    ],
    [
        '.###.',
        '#...#',
        '#....',
        '#....',
        '#..##',
        '#...#',
        '.###.',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '#####',
        '#...#',
        '#...#',
        '#...#',
    ],
    [
        '.###.',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
        '.###.',
    ],
    [
        '..###',
        '...#.',
        '...#.',
        '...#.',
        '...#.',
        '#..#.',
        '.##..',
    ],
    [
        '#...#',
        '#..#.',
        '#.#..',
        '##...',
        '#.#..',
        '#..#.',
        '#...#',
    ],
    [
        '#....',
        '#....',
        '#....',
        '#....',
        '#....',
        '#....',
        '#####',
    ],
    [
        '#...#',
        '##.##',
        '#.#.#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
    ],
    [
        '#...#',
        '#...#',
        '##..#',
        '#.#.#',
        '#..##',
        '#...#',
        '#...#',
    ],
    [
        '.###.',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '.###.',
    ],
    [
        '####.',
        '#...#',
        '#...#',
        '####.',
        '#....',
        '#....',
        '#....',
    ],
    [
        '.###.',
        '#...#',
        '#...#',
        '#...#',
        '#.#.#',
        '#..#.',
        '.##.#',
    ],
    [
        '####.',
        '#...#',
        '#...#',
        '####.',
        '#.#..',
        '#..#.',
        '#...#',
    ],
    [
        '.####',
        '#....',
        '#....',
        '.###.',
        '....#',
        '....#',
        '####.',
    ],
    [
        '#####',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '.###.',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '.#.#.',
        '..#..',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '#.#.#',
        '#.#.#',
        '##.##',
        '#...#',
    ],
    [
        '#...#',
        '#...#',
        '.#.#.',
        '..#..',
        '.#.#.',
        '#...#',
        '#...#',
    ],
    [
        '#...#',
        '#...#',
        '.#.#.',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
    ],
    [
        '#####',
        '....#',
        '...#.',
        '..#..',
        '.#...',
        '#....',
        '#####',
    ],
]

TEST_DATA = [
    [
        '..#..',
        '.#.#.',
        '#...#',
        '#...#',
        '#####',
        '#...#',
        '#...#',
    ],
    [
        '.###.',
        '#...#',
        '#...#',
        '####.',
        '#...#',
        '#...#',
        '####.',
    ],
    [
        '.###.',
        '#...#',
        '#....',
        '#....',
        '#....',
        '#...#',
        '.###.',
    ],
    [
        '####.',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '####.',
    ],
    [
        '#####',
        '#....',
        '#....',
        '###..',
        '#....',
        '#....',
        '#####',
    ],
    [
        '#####',
        '#....',
        '#....',
        '####.',
        '#....',
        '#....',
        '#....',
    ],
    [
        '.###.',
        '#...#',
        '#....',
        '#..##',
        '#...#',
        '#...#',
        '.###.',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '#####',
        '#...#',
        '#...#',
        '#...#',
    ],
    [
        '.###.',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
        '.###.',
    ],
    [
        '....#',
        '....#',
        '....#',
        '....#',
        '#...#',
        '#...#',
        '.###.',
    ],
    [
        '#...#',
        '#..#.',
        '#.#..',
        '##...',
        '#.#..',
        '#..#.',
        '#...#',
    ],
    [
        '#....',
        '#....',
        '#....',
        '#....',
        '#....',
        '#....',
        '#####',
    ],
    [
        '#...#',
        '##.##',
        '#.#.#',
        '#.#.#',
        '#...#',
        '#...#',
        '#...#',
    ],
    [
        '#...#',
        '##..#',
        '#.#.#',
        '#..##',
        '#...#',
        '#...#',
        '#...#',
    ],
    [
        '.###.',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '.###.',
    ],
    [
        '####.',
        '#...#',
        '#...#',
        '####.',
        '#....',
        '#....',
        '#....',
    ],
    [
        '.###.',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '.###.',
        '....#',
    ],
    [
        '####.',
        '#...#',
        '#...#',
        '####.',
        '#...#',
        '#...#',
        '#...#',
    ],
    [
        '.###.',
        '#...#',
        '#....',
        '.###.',
        '....#',
        '#...#',
        '.###.',
    ],
    [
        '#####',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
        '..#..',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '.###.',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '.#.#.',
        '..#..',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '#...#',
        '#.#.#',
        '##.##',
        '#...#',
    ],
    [
        '#...#',
        '.#.#.',
        '..#..',
        '..#..',
        '..#..',
        '.#.#.',
        '#...#',
    ],
    [
        '#...#',
        '#...#',
        '#...#',
        '.#.#.',
        '..#..',
        '..#..',
        '..#..',
    ],
    [
        '#####',
        '....#',
        '...#.',
        '..#..',
        '.#...',
        '#....',
        '#####',
    ],
]

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def char2vec(char):
    if char == '.':
        return -1
    else:
        return 1

    
def convertChar(X: list):
    X1 = [[0]*len((X[0]))]*len(X)
    xtemp = list()
    X2 = list(list())
    
    for i in range(len(X)):
        for j in range(len(X[0])):
            c = X[i][j]


            if X[i][j] == ".":
                xtemp.append(0)
            elif X[i][j] == "#":
                xtemp.append(1)


        temp = xtemp.copy()
        xtemp.clear()
        X2.append(temp)
    

    return X2

# %%
def threshold(y: int):
    if y >= 0:
        return 1
    else:
        return 0

# %%
def init_weights(X:list) -> list:
    weights = list()
    index = 0
    for i in range(len(X)):
        for j in range(len(X[0])):
            weights.insert(index, random.uniform(0,1))
            index += 1
    return weights

# %%
def predict(X:list, weights:list, b: int):
    y_pred = (np.dot(weights.T, X) + b)
    y_pred = threshold(y_pred)
    return y_pred

# %%
#init weights

X = np.array(TRAINING_DATA)
weights = []
for i in X:
    a = init_weights(i)
    weights.append(a)
    
weights = np.array(weights)

# %%
#init x and convert to 0/1
x1 = []

for i in X:
    a = convertChar(i)
    x1.append(a.copy())
    
x = np.array(x1)
x = x.reshape(26,35)

# %%
learning_rate = .03

# %%
#making bias list

b = []

for i in range(26):
    b.append(random.random())

# %%
#init y
y = np.identity(26)

# %%
#this one works, but b doesnt get updated. I realized that this is passing in an int and not the entire 
#list which is why its not being updated, but when I went to fix that it still wouldnt work. 
#This is the closest i've gotten

def learning_algh(neuron_num: int, b: list, epoch_count):
    
    #how many epochs
    for epoch in range(epoch_count):
        
        for i in range(len(x)):
            #prediction    
            pred = predict(x[i], weights[neuron_num], b[neuron_num])
            #error
            error = (y[i][neuron_num] - pred)
            
            #update weights
            for j in range(35):
                weights[neuron_num][j] += (learning_rate * error * x[i][j])
                
            #update bias
            b[neuron_num] += (learning_rate * error)

# %%
#training model

for i in range(26):
    learning_algh(i, b, 100)
    print(f'training neuron: {i} ')
# Out:
# training neuron: 0
# training neuron: 1
# training neuron: 2
# training neuron: 3
# training neuron: 4
# training neuron: 5
# training neuron: 6
# training neuron: 7
# training neuron: 8
# training neuron: 9
# training neuron: 10
# training neuron: 11
# training neuron: 12
# training neuron: 13
# training neuron: 14
# training neuron: 15
# training neuron: 16
# training neuron: 17
# training neuron: 18
# training neuron: 19
# training neuron: 20
# training neuron: 21
# training neuron: 22
# training neuron: 23
# training neuron: 24
# training neuron: 25

# %%
#evaluating training data

for i in range(26):
    A2 = 'A'
    print(f'neuron: {chr(ord(A2)+i)}')
    for j in range(26):
        A1 = 'A'
        pred = predict(x[i],weights[j],b[j])
        str1 = f'{chr(ord(A1)+j)} : {pred}'
        print(str1)
    print()
# Out:
# neuron: A
# A : 1
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: B
# A : 0
# B : 1
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: C
# A : 0
# B : 0
# C : 1
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: D
# A : 0
# B : 0
# C : 0
# D : 1
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: E
# A : 0
# B : 0
# C : 0
# D : 0
# E : 1
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: F
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 1
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: G
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 1
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: H
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 1
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: I
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 1
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: J
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 1
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: K
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 1
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: L
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 1
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: M
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 1
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: N
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 1
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: O
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 1
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: P
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 1
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: Q
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 1
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: R
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 1
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: S
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 1
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: T
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 1
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: U
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 1
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: V
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 1
# W : 0
# X : 0
# Y : 0
# Z : 0
#
# neuron: W
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 1
# X : 0
# Y : 0
# Z : 0
#
# neuron: X
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 1
# Y : 0
# Z : 0
#
# neuron: Y
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 1
# Z : 0
#
# neuron: Z
# A : 0
# B : 0
# C : 0
# D : 0
# E : 0
# F : 0
# G : 0
# H : 0
# I : 0
# J : 0
# K : 0
# L : 0
# M : 0
# N : 0
# O : 0
# P : 0
# Q : 0
# R : 0
# S : 0
# T : 0
# U : 0
# V : 0
# W : 0
# X : 0
# Y : 0
# Z : 1
